# %%
import silq
silq.initialize("EWJN", mode='analysis')
# %matplotlib notebook
# Out:
# Initializing imports
# Initializing functions
# Initializing data
# Initializing analysis
# Initializing plotting
# Initialization complete

# %% [markdown]
# # Calibration

# %%
data = qc.load_data('2016-12-02/#001_DC_TGAC_vs_DF_DS_scan_09-54-08')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-12-02/#002_EPR_calibration_10-21-12')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
#plot.add(data.fidelity_read, subplot=4, nticks=6)
plot.add(data.up_proportion, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-12-02/#007_DC_TGAC_vs_DF_DS_scan_11-52-36')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-12-02/#008_DC_TGAC_vs_DF_DS_scan_12-32-16')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-12-02/#010_DC_TGAC_vs_DF_DS_scan_12-50-16')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-12-02/#011_DC_TGAC_vs_DF_DS_scan_12-56-03')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-12-02/#012_EPR_calibration_13-01-45')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
#plot.add(data.fidelity_read, subplot=4, nticks=6)
plot.add(data.up_proportion, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-12-02/#013_EPR_calibration_13-44-48')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
#plot.add(data.fidelity_read, subplot=4, nticks=6)
plot.add(data.up_proportion, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-12-02/#013_EPR_calibration_13-44-48')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
#plot.add(data.fidelity_read, subplot=4, nticks=6)
plot.add(data.up_proportion, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# not that great (also on 20 samples, only realized after). looking for second coulomb peak.
# Where is it???

# %%
data = qc.load_data('2016-12-02/#015_DC_TGAC_vs_DF_DS_scan_14-03-04')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-12-02/#016_DC_TGAC_vs_DF_DS_scan_14-12-05')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-12-02/#017_EPR_calibration_14-20-16')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
#plot.add(data.fidelity_read, subplot=4, nticks=6)
plot.add(data.up_proportion, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# pretty bad but also only 20 samples

# %%
data = qc.load_data('2016-12-02/#019_EPR_calibration_14-33-19')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
#plot.add(data.fidelity_read, subplot=4, nticks=6)
plot.add(data.up_proportion, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# redo first coulomb peak with 100 samples

# %%
data = qc.load_data('2016-12-02/#020_EPR_calibration_14-42-56')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
#plot.add(data.fidelity_read, subplot=4, nticks=6)
plot.add(data.up_proportion, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-12-02/#022_adiabatic_sweep_16-23-34')
qc.MatPlot(data.up_proportion)
# Out:
# <img src="data:image/png;base64,...">

# %%
T1_dataset = T1_Dataset('2016-12-02/#036_T1_data_21-57-51', T1_label='up_proportion_5_0_0', skip=list(range(10, 30)))

plot = qc.MatPlot(T1_dataset.dataset.up_proportion_5_0_0)
plt.ylabel('Scan number')
plot.subplots[0].set_xscale("log", nonposx='clip')
# Out:
# Number of successful sweeps: 29
# <img src="data:image/png;base64,...">

# %%
T1_dataset.T1_data = T1_dataset.T1_data[:16]

# %%
T1_dataset.analyse_T1_data()
# Out:
# (array([ 0.92873312,  0.91161162,  0.9222235 ,  0.87861425,  0.83338119,
#          0.77821312,  0.65762994,  0.47732487,  0.37138644,  0.28102763]),
#  array([ 0.02613856,  0.03233232,  0.01985961,  0.03606555,  0.03870723,
#          0.05036448,  0.0429592 ,  0.05894502,  0.07247728,  0.04750866]),
#  array([ 0.00653464,  0.00808308,  0.0049649 ,  0.00901639,  0.00967681,
#          0.01259112,  0.0107398 ,  0.01473625,  0.01811932,  0.01187717]))

# %%
T1_Measurement('2016-12-02/#036_T1_data_21-57-51', 0.85, T1_label='up_proportion_5_0_0', skip=list(range(10, 30)))
# Out:
# Number of successful sweeps: 29
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-fd5aeea8335e> in <module>()
# ----> 1 T1_Measurement('2016-12-02/#036_T1_data_21-57-51', 0.85, T1_label='up_proportion_5_0_0', skip=list(range(10, 30)))
#
# <string> in __init__(self, location, B0, T1_label, skip)
#
# <string> in add_data(self, location, T1_label, T1_wait_time, skip)
#
# <string> in fit_T1(self, T1_wait_times, T1_data_mean, datasets, weights)
#
# C:\Users\lab.BluG12Meas\Documents\SilQ\silq\analysis\fit_toolbox.py in perform_fit(self, xvals, ydata, initial_parameters, weights, options)
#      53         super().__init__()
#      54
# ---> 55         parameters=self.find_initial_parameters(xvals, ydata, initial_parameters)
#      56
#      57         return self.model.fit(ydata, t=xvals, params=parameters, weights=weights)
#
# C:\Users\lab.BluG12Meas\Documents\SilQ\silq\analysis\fit_toolbox.py in find_initial_parameters(self, xvals, ydata, initial_parameters)
#      39         if not 'tau' in initial_parameters:
#      40             initial_parameters['tau'] = -(xvals[1] - xvals[np.where(
# ---> 41                 self.find_nearest_index(ydata, ydata[0] / np.exp(1)) == ydata)[0][0]])
#      42         if not 'amplitude' in initial_parameters:
#      43             initial_parameters['amplitude'] = ydata[1]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
