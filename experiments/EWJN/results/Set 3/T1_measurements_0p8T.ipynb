# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Calibration" data-toc-modified-id="Calibration-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Calibration</a></div>

# %%
import silq
silq.initialize("EWJN", mode='analysis')
# %matplotlib notebook
# Out:
# Initializing imports
# Initializing functions
# Initializing data
# Initializing analysis
# Initializing plotting
# Initialization complete

# %% [markdown]
# # Calibration

# %%
data = qc.load_data('2016-12-03/#009_DC_TGAC_vs_DF_DS_scan_20-57-44')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-12-03/#010_DC_TGAC_vs_DF_DS_scan_21-05-37')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Found a spot with some contrast:
# TGAC(0.48768)
# DF_DS(0.4206)
#
# fidelity_empty: 0.507
# fidelity_load: 0.961
# fidelity_read: 0.700
# up_proportion: 0.288
# dark_counts: 0.055
# contrast: 0.232
#
# Next step is to tune ESR, which is proving to be quite difficult.
# There are some frequencies with high contrast, but these frequencies change from scan to scan.
# As an example, below two scans are shown with identical settings, both with a 40 MHz adiabatic frequency window.

# %%
# 40 MHz window
data = qc.load_data('2016-12-04/#014_adiabatic_sweep_12-04-55')
qc.MatPlot(data.contrast);
# Out:
# <img src="data:image/png;base64,...">

# %%
# 40 MHz window, same meaurement settings, performed right after
data = qc.load_data('2016-12-04/#015_adiabatic_sweep_12-16-19')
qc.MatPlot(data.contrast);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# It is clear that the results differ significantly, although the reason why is not clear.
# One other interesting point is that in the second scan, the frequency range with high contrast is around 200 MHz, much higher that the 40 MHz window.
# This suggests that the actual resonance frequency could also be shifting, which would indicate a changing magnetic field.
#
# As a check, we perform a scan at the same frequency (22.376 GHz), with 450 samples.
# The results below show that the contrast switches between high and low.
# I do not know why the high contrast is significantly lower than before, perhaps the energy landscape shifted resulting in a less optimal voltage point.

# %%
# 40 MHz window, Repeatedly scanning the same point over time
data = qc.load_data('2016-12-04/#018_{name}_12-59-08')
plot = qc.MatPlot(data.contrast);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# The next day the point was out of tune, and thus had to be retuned

# %%
data = qc.load_data('2016-12-05/#004_EPR_calibration_10-00-10')
plot = plot_calibration(data)
plot.subplots[0].qcodes_colorbar.set_clim(0, 0.4)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# DF_DS(0.4214)
# TGAC(0.4842)
# fidelity_empty: 0.510
# fidelity_load: 0.766
# fidelity_read: 0.677
# up_proportion: 0.341
# dark_counts: 0.075
# contrast: 0.266

# %%
# 40 MHz window
data = qc.load_data('2016-12-05/#005_adiabatic_sweep_12-30-23')
qc.MatPlot(data.contrast);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# saw resonance and then it disappeared again (small window scan), but constrast is still 26%...
# After another large window scan, the constrast was gone.

# %%
data = qc.load_data('2016-12-05/#010_EPR_calibration_13-19-01')
plot = plot_calibration(data)
# Out:
# <img src="data:image/png;base64,...">

# %%
DF_DS(0.4215)
TGAC(0.4832)
fidelity_empty: 0.595
fidelity_load: 0.778
fidelity_read: 0.762
up_proportion: 0.338
dark_counts: 0.083
contrast: 0.256

# %%
# 40 MHz window
data = qc.load_data('2016-12-05/#011_adiabatic_sweep_13-37-05')
qc.MatPlot(data.contrast);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# second scan showed no peak at all but still
# fidelity_empty: 0.520
# fidelity_load: 1.000
# fidelity_read: 0.827
# up_proportion: 0.291
# dark_counts: 0.134
# contrast: 0.157

# %%
# 40 MHz window
data = qc.load_data('2016-12-05/#023_adiabatic_sweep_14-15-06')
qc.MatPlot(data.contrast);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Clear shift of the resonance. We now perform a combination of EPR and the adiabatic sweep around resonance (22.30 GHz)

# %%
# 40 MHz window
data = qc.load_data('2016-12-05/#024_{name}_14-19-02')
plot = qc.MatPlot(data.contrast_1_5)
plot.add(data.contrast_3_4);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# As time progresses, the contrast for the adiabatic sweeping clearly drops, indicating that the resonance frequency has shifted
