# %%
import silq
silq.initialize("EWJN", mode='analysis')
# %matplotlib notebook
# Out:
# Initializing imports
# <style>.qcodes-output-view:not(.ui-draggable) {
#     bottom: 0;
#     right: 5px;
# }
# .qcodes-output-view {
#     position: fixed;
#     z-index: 999;
#     background-color: #fff;
#     box-shadow: 0 0 12px 1px rgba(87, 87, 87, 0.2);
# }
#
# .qcodes-output-header {
#     float: right;
# }
#
# .qcodes-highlight {
#     animation: pulse 1s linear;
#     background-color: #fa4;
# }
#
# @keyframes pulse {
#     0% {
#         background-color: #f00;
#     }
#     100% {
#         background-color: #fa4;
#     }
# }
#
# .qcodes-process-list {
#     float: left;
#     max-width: 780px;
#     margin: 3px 5px 3px 10px;
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
# .qcodes-output-view[qcodes-state=minimized] .qcodes-process-list {
#     max-width: 300px;
# }
#
# .qcodes-output-view span {
#     padding: 2px 6px 3px 12px;
# }
#
# .qcodes-output-view .btn {
#     margin: 0 3px 0 0;
# }
#
# ...

# %% [markdown]
# # Measurement set 1

# %%
data = qc.load_data('2016-11-21/#001_DC_TGAC_vs_DF_DS_scan_10-28-18')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-11-21/#002_ELR_calibration_10-35-53')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Adiabatic Sweep without steering

# %%
data = qc.load_data('2016-11-21/#003_adiabatic_sweep_10-52-20')
qc.MatPlot(data.contrast)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # LR scan with steered initialization

# %%
data = qc.load_data('2016-11-21/#005_adiabatic_calibration_11-08-05')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
#plot.add(data.fidelity_read, subplot=4, nticks=6)
plot.add(data.up_proportion, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-11-21/#008_T1_single_sweep_12-21-58')
qc.MatPlot(data.up_proportion)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # T1 scan

# %%
T1_msmt = T1_Measurement(B0=1.2, location='2016-11-21/#010_T1_data_13-52-39')
T1_msmt.plot_T1()
print(T1_msmt.fit_result.fit_report())
# Out:
# Number of successful sweeps: 2
# <img src="data:image/png;base64,...">
# [[Model]]
#     Model(fit_function)
# [[Fit Statistics]]
#     # function evals   = 27
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 58331790186.844
#     reduced chi-square = 3431281775.697
#     Akaike info crit   = 441.874
#     Bayesian info crit = 444.861
# [[Variables]]
#     offset:      0.18582286 +/- 0.048907 (26.32%) (init= 0.238559)
#     amplitude:   0.70883603 +/- 0.047276 (6.67%) (init= 0.895672)
#     tau:         2163.08912 +/- 327.2967 (15.13%) (init= 3788.001)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(offset, amplitude)         = -0.978
#     C(offset, tau)               = -0.900
#     C(amplitude, tau)            =  0.840

# %% [markdown]
# # Measurement set 2

# %% [markdown]
# ## LR scan with steered initialization

# %%
data = qc.load_data('2016-11-21/#011_adiabatic_calibration_15-44-10')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
#plot.add(data.fidelity_read, subplot=4, nticks=6)
plot.add(data.up_proportion, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
TGAC(0.340)
DF_DS(0.482)
fidelity_load: 0.000
fidelity_read: 0.704
up_proportion: 0.919
dark_counts: 0.135
contrast: 0.784
    
Plunge Depth 1.5V

# %% [markdown]
# ## Adiabatic sweep tests

# %%
data = qc.load_data('2016-11-21/#012_adiabatic_sweep_16-29-48')
qc.MatPlot(data.contrast)
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-11-21/#013_T1_single_sweep_16-39-36')
qc.MatPlot(data.up_proportion)
# Out:
# <img src="data:image/png;base64,...">

# %%
T1_msmt = T1_Measurement(B0=1.2, location='2016-11-21/#016_T1_data_18-02-24')
T1_msmt.plot_T1()
print(T1_msmt.fit_result.fit_report())
# Out:
# Number of successful sweeps: 28
# <img src="data:image/png;base64,...">
# [[Model]]
#     Model(fit_function)
# [[Fit Statistics]]
#     # function evals   = 19
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 8515448938307.181
#     reduced chi-square = 500908761076.893
#     Akaike info crit   = 541.543
#     Bayesian info crit = 544.531
# [[Variables]]
#     tau:         1819.32345 +/- 42.20437 (2.32%) (init= 2553.281)
#     offset:      0.19943466 +/- 0.007191 (3.61%) (init= 0.2338224)
#     amplitude:   0.73275390 +/- 0.006986 (0.95%) (init= 0.9347215)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(offset, amplitude)         = -0.965
#     C(tau, offset)               = -0.866
#     C(tau, amplitude)            =  0.778

# %% [markdown]
# TGAC(0.347)
# DF_DS(0.4786)
# after mesaurement LR parameter:
# fidelity_load: 0.000
# fidelity_read: 0.664
# up_proportion: 0.898
# dark_counts: 0.092
# contrast: 0.806
#
# Plunge depth 1.8V
#
# frequency_center = 33.568e9
# T1_parameter.pulse_sequence['adiabatic_sweep'].frequency_deviation=10e6
# T1_parameter.pulse_sequence['adiabatic_sweep'].duration = 0.2
# power = 10dBm

# %%
fidelity_load: 0.000
fidelity_read: 0.689
up_proportion: 0.914
dark_counts: 0.141
contrast: 0.773

# %%
T1_msmt_deepP = T1_Measurement(B0=1.2, location='2016-11-23/#006_T1_data_14-50-59')
T1_msmt_deepP.plot_T1()
print(T1_msmt_deepP.fit_result.fit_report())
# Out:
# Number of successful sweeps: 3
# <img src="data:image/png;base64,...">
# [[Model]]
#     Model(fit_function)
# [[Fit Statistics]]
#     # function evals   = 31
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 268058686009.508
#     reduced chi-square = 15768158000.559
#     Akaike info crit   = 472.375
#     Bayesian info crit = 475.362
# [[Variables]]
#     tau:         3175.10984 +/- 468.5274 (14.76%) (init= 5618.721)
#     offset:      0.12918779 +/- 0.062306 (48.23%) (init= 0.2443097)
#     amplitude:   0.77915973 +/- 0.060463 (7.76%) (init= 0.936128)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(offset, amplitude)         = -0.993
#     C(tau, offset)               = -0.953
#     C(tau, amplitude)            =  0.932

# %%
plot=qc.MatPlot(T1_msmt.T1_data_mean)
plot.add(T1_msmt_deepP.T1_data_mean)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ELR parameter:
# fidelity_empty: 0.866
# fidelity_load: 1.000
# fidelity_read: 0.743
# up_proportion: 0.605
# dark_counts: 0.146
# contrast: 0.460
