# %%
import silq
silq.initialize("EWJN", mode='analysis')
# %matplotlib notebook
# Out:
# Initializing imports
# Initializing functions
# Initializing data
# Initializing analysis
# Initializing plotting
# Initialization complete

# %% [markdown]
# # Set 2

# %% [markdown]
# At some point the battery of TGAC was dead, and so this was replaced.

# %%
data = qc.load_data('2016-10-31/#009_DC_TGAC_vs_DF_DS_scan_14-40-40')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Set 1

# %%
data = qc.load_data('2016-10-25/#002_ELRLR_calibration_11-12-03')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-26/#004_ELRLR_calibration_17-56-19')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot[0].add(data.contrast, nticks=6)
plot[1].add(data.dark_counts, nticks=6)
plot[2].add(data.fidelity_load, nticks=6)
plot[3].add(data.fidelity_empty, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
data = qc.load_data('2016-10-26/#006_ELRLR_calibration_20-37-41')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-27/#001_ELRLR_calibration_10-01-55')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Code after implementing new Layout architecture

# %%
data = qc.load_data('2016-10-28/#020_DC_TGAC_vs_DF_DS_scan_18-43-51')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-28/#028_ELR_calibration_19-07-47')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-28/#029_ELR_calibration_19-32-33')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-29/#002_ELR_calibration_08-05-40')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# data = qc.load_data('2016-10-18/#002_variable_read_14-11-31')
# qc.MatPlot(data.Channel_A_signal);

# %% [markdown]
# T1_msmt = T1_Measurement(B0=0.8, location='2016-10-20/#006_T1_data_18-29-59')
# T1_msmt.plot_T1()
# plt.ylim(0,0.7)
# print(T1_msmt.fit_result.fit_report())

# %% [markdown]
# TG_raw(16.48)
# LB_raw(3.92)
# RB_raw(3.92)
# TGAC_raw(3.0)
# SRC_raw(0.15)
# DF_raw(1.872)
# DS_raw(1.872)
