# %%
import silq
silq.initialize("EWJN", mode='analysis')
# %matplotlib notebook
# Out:
# Initializing imports
# <style>.qcodes-output-view:not(.ui-draggable) {
#     bottom: 0;
#     right: 5px;
# }
# .qcodes-output-view {
#     position: fixed;
#     z-index: 999;
#     background-color: #fff;
#     box-shadow: 0 0 12px 1px rgba(87, 87, 87, 0.2);
# }
#
# .qcodes-output-header {
#     float: right;
# }
#
# .qcodes-highlight {
#     animation: pulse 1s linear;
#     background-color: #fa4;
# }
#
# @keyframes pulse {
#     0% {
#         background-color: #f00;
#     }
#     100% {
#         background-color: #fa4;
#     }
# }
#
# .qcodes-process-list {
#     float: left;
#     max-width: 780px;
#     margin: 3px 5px 3px 10px;
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
# .qcodes-output-view[qcodes-state=minimized] .qcodes-process-list {
#     max-width: 300px;
# }
#
# .qcodes-output-view span {
#     padding: 2px 6px 3px 12px;
# }
#
# .qcodes-output-view .btn {
#     margin: 0 3px 0 0;
# }
#
# ...

# %% [markdown]
# # Tuning after changing LB (12 Oct)

# %% [markdown]
# In the previous cooldown (see below), it was concluded that the left barrier was floating.
# We warmed up the fridge and found out that indeed the connection was open between sample and breakout box.
# We then switched the LB channel from 3 to 1.
#
# First we perform global turnon, without any SD bias

# %%
data = qc.load_data('2016-10-12/#001_turnon_13-19-31')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# This is the same global turnon measurement, but with SD bias SRC(0.25)

# %%
data = qc.load_data('2016-10-12/#002_turnon_13-24-18')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Turnon seems good, as a check the voltages are kept at 1.4V and measured for 15 mins

# %%
data = qc.load_data('2016-10-12/#003_turnon_13-31-20')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Everything seems stable, now performing pinchoff while turnon_voltage(1.9)

# %%
# Using other dataset because it uses scaled parameters
# data = qc.load_data('2016-10-12/#009_Pinchoff_LB_14-13-41')
data = qc.load_data('2016-10-12/#012_Pinchoff_LB_15-49-03')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# LB versus RB scan
# TG fixed at TG(1.9)

# %%
data = qc.load_data('2016-10-12/#016_DC_LB_RB_scan_18-20-37')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# It seems that near (RB, LB) = (1.1, 1.05), we have coulomb oscillations, but the resolution is too low.
# Zooming into that region

# %%
data = qc.load_data('2016-10-12/#017_DC_LB_RB_scan_20-29-55')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Even closer zoom in

# %%
data = qc.load_data('2016-10-12/#018_DC_LB_RB_scan_20-36-48')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Performing a scan of TG versus TGAC,DF,DS combined
# LB, RB at 1.06

# %%
data = qc.load_data('2016-10-12/#029_DC_TGAC_DF_DS_vs_TG_scan_20-59-52')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-12/#030_DC_LB_RB_vs_TG_scan_21-09-45')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Settin LB and RB to 1V

# %%
data = qc.load_data('2016-10-12/#031_DC_TGAC_DF_DS_vs_TG_scan_21-13-39')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# DF_DS scan vs TGAC, with TG(1.71)

# %%
data = qc.load_data('2016-10-12/#032_DC_DF_DS_vs_TGAC_scan_21-20-28')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-13/#002_DC_DF_DS_vs_TGAC_scan_LBRB_1_TG_1p7_07-46-02')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-13/#003_DC_DF_DS_vs_TGAC_scan_LBRB_1_TG_1p8_08-26-43')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Zooming into a small region, and switching TGAC and DF_DS

# %%
data = qc.load_data('2016-10-13/#005_DC_TGAC_vs_DF_DS_scan_09-11-28')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Something strange is gong on, since the shift seems to be in the wrong direction.
# Also, the transition is not pixely, but smudged.
#
# As a check, the system is reset to the voltages before the initial shutdown, to see if perhaps the donor is still where it used to be

# %%
data = qc.load_data('2016-10-13/#009_DC_TGAC_vs_DF_DS_scan_09-28-13')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# The donor might well be at the bottom right. Increasing TG from ~1.95 to TG(2.05)

# %%
data = qc.load_data('2016-10-13/#016_DC_TGAC_vs_DF_DS_scan_10-19-02')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Not much has changed since increasing TG.
# The contrast seems slightly low at the bottom right, so I am increasing LB_RB, and zooming in on the region near the donor

# %%
data = qc.load_data('2016-10-13/#021_DC_TGAC_vs_DF_DS_scan_10-44-33')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# The contrast has definitely increased, and the results are starting to look like those before cooldown.
#
# Now changing the magnetic field to 1.2T, I took several 2D scans after changing the field to see how this affects the charge landscape (see below)
#
# After two hours, the charge landscape seems to have settled

# %%
data = qc.load_data('2016-10-13/#026_DC_TGAC_vs_DF_DS_scan_12-37-10')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-13/#027_ELRLR_calibration_12-57-08')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Another ELRLR scan, but a bit to the bottom right, and increasing load duration to 40ms

# %%
data = qc.load_data('2016-10-13/#030_ELRLR_calibration_13-32-46')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Having difficulty finding the good regions, also when looking for blips.

# %%
data = qc.load_data('2016-10-13/#032_DC_TGAC_vs_DF_DS_scan_14-15-04')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-13/#033_ELRLR_calibration_14-40-34')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-13/#035_ELRLR_calibration_15-49-24')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data( '2016-10-13/#038_ELRLR_calibration_17-19-41')
plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# At operating point:
# TGAC(0.306)
# DF_DS(0.5025)
#
# fidelity_empty: 1.000
# fidelity_load: 0.963
# fidelity_read: 0.750
# up_proportion: 0.609
# dark_counts: 0.209
# contrast: 0.401

# %%
data = qc.load_data('2016-10-13/#039_variable_read_19-05-45')
qc.MatPlot(data.Channel_A_signal)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Measuring multiple 2D scans after magnetic field sweep (13 Oct)

# %% [markdown]
# To study the effects of changing the magnetic field, successive 2D scans were taken of the same region before and after changing the magnetic field from 0T to 1.2T.
#
# The first scan is taken before changing the field, the subsequent ones were taken after changing the field

# %%
data = qc.load_data('2016-10-13/#021_DC_TGAC_vs_DF_DS_scan_10-44-33')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-13/#021_DC_TGAC_vs_DF_DS_scan_10-44-33')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-13/#024_DC_TGAC_vs_DF_DS_scan_11-49-19')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-13/#025_DC_TGAC_vs_DF_DS_scan_12-05-51')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-13/#026_DC_TGAC_vs_DF_DS_scan_12-37-10')
qc.MatPlot(data.DC_voltage);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Tuning after power shutdown (6 Oct)

# %% [markdown]
# ### Global turnon

# %% [markdown]
# Performed a global turnon at SD voltage 0.25V.
# simultaneously sweeping TG, LB, and RB.

# %%
data = qc.load_data('2016-10-06/#007_turnon_sweep_08-56-42')
qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Turnon has increased significantly since before the warmup, this is a bad sign. Clipping can also be seen at 2V, due to the voltage limit of the digitizer.
#
# Redoing measurements, starting at higher voltage, and with a high voltage limit.

# %%
data = qc.load_data('2016-10-06/#011_turnon_sweep_09-14-52')
qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# The turnon voltage and shape has changed completely. I have no idea why.
#
# Performing additional scans for the full range 0V - 2V. When ramping down I ramp in steps of 0.5V

# %%
data = qc.load_data('2016-10-06/#012_turnon_sweep_09-31-10')
qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-06/#013_turnon_sweep_09-37-45')
qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# We can see that the turnon voltage changes quite dramatically. As a test, the voltage is kept fixed at 1.3V, and the current was measured for 15 mins.

# %%
data = qc.load_data('2016-10-06/#015_turnon_1p3V_fixed_10-11-06')
plot = qc.MatPlot(data.DC_voltage)
plot.subplots[0].set_xlabel('Time (s)')
# Out:
# C:\Users\lab.BluG12Meas\Anaconda3\lib\site-packages\matplotlib\pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %% [markdown]
# There is quite a significant drift. Next we attempt to perform pinchoff on the left barrier, while the others are kept at 1.3V. Note that the x-axis has a scaling of 4x.

# %%
data = qc.load_data('2016-10-06/#018_pinchoff_LB_10-34-14')
qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# No signal, this likely means that the turnon voltage has shifted. Indeed when I increase the combined voltage to 1.6V, we measure a DC voltage 1.2V.
#
# Next we measure pinchoff again, starting at 1.5V

# %%
data = qc.load_data('2016-10-06/#019_pinchoff_LB_10-40-34')
qc.MatPlot(data.DC_voltage)
# Out:
# C:\Users\lab.BluG12Meas\Anaconda3\lib\site-packages\matplotlib\pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %% [markdown]
# Next we perform the same measurement for the right barrier

# %%
data = qc.load_data('2016-10-06/#020_pinchoff_RB_10-42-40')
qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# It seems the turnon voltage has yet again shifted.

# %%
data = qc.load_data('2016-10-06/#022_pinchoff_RB_10-45-39')
qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-10-06/#026_turnon_1p7V_LB_1p7V_fixed_14-56-30')
qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">
