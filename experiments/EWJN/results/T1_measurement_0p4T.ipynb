# %%
import silq
silq.initialize("EWJN", mode='analysis')
# %matplotlib notebook
# Out:
# Initializing imports
# <style>.qcodes-output-view:not(.ui-draggable) {
#     bottom: 0;
#     right: 5px;
# }
# .qcodes-output-view {
#     position: fixed;
#     z-index: 999;
#     background-color: #fff;
#     box-shadow: 0 0 12px 1px rgba(87, 87, 87, 0.2);
# }
#
# .qcodes-output-header {
#     float: right;
# }
#
# .qcodes-highlight {
#     animation: pulse 1s linear;
#     background-color: #fa4;
# }
#
# @keyframes pulse {
#     0% {
#         background-color: #f00;
#     }
#     100% {
#         background-color: #fa4;
#     }
# }
#
# .qcodes-process-list {
#     float: left;
#     max-width: 780px;
#     margin: 3px 5px 3px 10px;
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
# .qcodes-output-view[qcodes-state=minimized] .qcodes-process-list {
#     max-width: 300px;
# }
#
# .qcodes-output-view span {
#     padding: 2px 6px 3px 12px;
# }
#
# .qcodes-output-view .btn {
#     margin: 0 3px 0 0;
# }
#
# .qcodes-output-view[qcodes-state=docked] .qcodes-docked,
# .qcodes-output-view[qcodes-state=floated] .qcodes-floated,
# .qcodes-output-view[qcodes-state=minimized] .qcodes-minimized,
# .qcodes-output-view[qcodes-state=minimized] .qcodes-content {
#     display: none;
# }
#
# .qcodes-output-view .disabled {
#     opacity: 0.4;
# }
#
# .qcodes-abort-loop {
#     background-color: #844;
#     color: #fff;
# }
#
# .qcodes-output-view pre {
#     clear: both;
#     margin: 0;
#     border: 0;
#     border-top: 1px solid #ccc;
#     background-color: #ffe;
#     min-height: 50px;
#     max-height: 400px;
#     min-width: 400px;
#     max-width: 1000px;
# }</style>
# Initializing functions
# Initializing data
# Initializing analysis
# Initializing plotting
# Initialization complete

# %%
data = qc.load_data('2016-09-20/#001_DC_sweep_10-09-19')
plot = qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-20/#002_DC_sweep_10-15-11')
plot = qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# The peak seems roughly at the same position. I am now checking what the contrast is at the previous operating point.
#
# TGAC(1.837)
# DF_DS(2.57)
#
# fidelity_empty: 0.979
# fidelity_load: 0.832
# fidelity_read: 0.717
# up_proportion: 0.470
# dark_counts: 0.317
# contrast: 0.153
#
# There might be room for improvement

# %%
data = qc.load_data('2016-09-20/#033_ELRLR_calibration_11-50-21')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# changed read duration to 40ms for the ELRLR scan to reduce wrong up init

# %%
data = qc.load_data('2016-09-20/#035_ELRLR_calibration_13-28-33')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# TGAC(1.84)
# DF_DS(2.569)
# fidelity_empty: 0.990
# fidelity_load: 0.845
# fidelity_read: 0.644
# up_proportion: 0.591
# dark_counts: 0.324
# contrast: 0.267

# %%
data = qc.load_data('2016-09-20/#036_ELRLR_calibration_15-17-38')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-20/#037_ELRLR_calibration_16-01-55')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# operating point:
# TGAC(1.842)
# DF_DS(2.57)
# fidelity_empty: 0.996
# fidelity_load: 0.848
# fidelity_read: 0.686
# up_proportion: 0.574
# dark_counts: 0.323
# contrast: 0.251
#
# fidelity_empty: 0.994
# fidelity_load: 0.826
# fidelity_read: 0.676
# up_proportion: 0.564
# dark_counts: 0.336
# contrast: 0.228
# -> not very reliable, but better point seems not to exist

# %%
data = qc.load_data('2016-09-20/#038_variable_read_16-35-35')
plot = qc.MatPlot(data.Channel_A_signal)
# Out:
# <img src="data:image/png;base64,...">

# %%
T1_msmt = T1_Measurement(B0=1.2, location='2016-09-20/#040_T1_data_16-47-57')
T1_msmt.plot_T1()
print(T1_msmt.T1_fit_result.fit_report())
# Out:
# Number of successful sweeps: 9
# <img src="data:image/png;base64,...">
# [[Model]]
#     Model(fit_function)
# [[Fit Statistics]]
#     # function evals   = 31
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 21061974.303
#     reduced chi-square = 1238939.665
#     Akaike info crit   = 283.345
#     Bayesian info crit = 286.332
# [[Variables]]
#     amplitude:   0.35381870 +/- 0.059149 (16.72%) (init= 0.429704)
#     tau:         7677.31493 +/- 2.36e+03 (30.72%) (init= 12574.74)
#     offset:      0.07666531 +/- 0.060944 (79.49%) (init= 0.1623664)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(amplitude, offset)         = -0.995
#     C(tau, offset)               = -0.961
#     C(amplitude, tau)            =  0.943
