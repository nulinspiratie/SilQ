# %%
import os
import numpy as np
from matplotlib import pyplot as plt

import qcodes as qc
from personal.tools import fit_toolbox
qc.data.data_set.DataSet.default_io.base_location = r'Q:\2-qubit\OC13 - Berdina BlueFors\EWJN\data'
#qc.data.data_set.DataSet.default_io.base_location = 'E:\EWJN\data'
loc_provider = qc.data.location.FormatLocation(fmt='{date}/#{counter}_{name}_{time}')
qc.data.data_set.DataSet.location_provider=loc_provider
# %matplotlib notebook

# %% [markdown]
# # Measurement set 3

# %% [markdown]
# We realized during the measurement of 4.5T that increasing the empty duration and the load voltage greatly increased the contrast. Furthermore, we found out that the postselection for measurements where the electron was successfully loaded, was in fact not working. Therefore we retook the measurement set at 4T.

# %%
data = qc.load_data('2016-09-11/#001_DC_sweep_00-00-43')
plotQ = qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-11/#002_DC_sweep_00-11-36')
plotQ = qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-11/#003_ELRLR_calibration_00-23-06')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-11/#004_ELRLR_calibration_00-39-36')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Position has shifted, redoing DC scan

# %%
data = qc.load_data('2016-09-11/#006_DC_sweep_00-53-31')
plotQ = qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-11/#007_ELRLR_calibration_00-59-59')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-11/#008_ELRLR_calibration_01-06-57')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-11/#009_ELRLR_calibration_01-12-45')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# TGAC(1.827)
# DF_DS(2.567)
#
# fidelity_empty: 0.992
# fidelity_load: 0.000
# fidelity_read: 0.782
# up_proportion: 0.525
# dark_counts: 0.022
# contrast: 0.502
#
# TGAC(1.78)
# DF_DS(2.58)
#
# fidelity_empty: 0.985
# fidelity_load: 0.980
# fidelity_read: 0.850
# up_proportion: 0.475
# dark_counts: 0.015
# contrast: 0.460

# %%
data = qc.load_data('2016-09-11/#010_ELRLR_calibration_01-20-03')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Operating point:
#
# TGAC(1.787)
# DF_DS(2.583)
#
# fidelity_empty: 0.972
# fidelity_load: 0.980
# fidelity_read: 0.812
# up_proportion: 0.489
# dark_counts: 0.020
# contrast: 0.469

# %%
data = qc.load_data('2016-09-11/#011_variable_read_01-24-55')
plot = qc.MatPlot(data.Channel_A_signal)
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-11/#014_T1_data_01-49-04')
T1_wait_times = data.T1_wait_time_set[0]
T1_wait_times_sorted = np.sort(T1_wait_times)
idx_sorted = np.argsort(T1_wait_times)

max_idx = np.argmin([~np.isnan(np.sum(datarow)) for datarow in data.up_proportion_3_0_0])
print('Number of successful sweeps: {}'.format(max_idx))
vals = data.up_proportion_3_0_0[:max_idx]
vals_sorted = vals[:,idx_sorted]
vals_mean_sorted = np.mean(vals_sorted,axis=0)
vals_std_sorted = np.std(vals_sorted,axis=0)
vals_std_mean_sorted = vals_std_sorted/np.sqrt(max_idx)


fig = plt.figure()
ax = fig.gca()
for datarow in vals_sorted:
    ax.plot(T1_wait_times_sorted, datarow, 'ok', ms=3, alpha=0.2)
(_, caps, _) = ax.errorbar(T1_wait_times_sorted, vals_mean_sorted, yerr=vals_std_mean_sorted, 
                           marker='o', linestyle='',ms=10)
for cap in caps:
    cap.set_markeredgewidth(3)
    
# Fitting 
mod = fit_toolbox.ExponentialFit()
result=mod.perform_fit(T1_wait_times_sorted,vals_mean_sorted)#, weights=1/np.power(vals_std_mean_sorted,2))
print('T1 time: {:.0f} ms'.format(result.best_values['tau']))
plt.plot(T1_wait_times_sorted, result.best_fit, 'r-')

ax.set_xscale("log")
ax.set_xlim([0.9*T1_wait_times_sorted[0], 1.1*T1_wait_times_sorted[-1]])
ax.set_ylim([0, 0.55])

ax.set_xlabel('Wait time (ms)')
ax.set_ylabel('Up population')
print(result.fit_report())
# Out:
# Number of successful sweeps: 21
# <img src="data:image/png;base64,...">
# T1 time: 676 ms
# [[Model]]
#     Model(fit_function)
# [[Fit Statistics]]
#     # function evals   = 19
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 0.001
#     reduced chi-square = 0.000
#     Akaike info crit   = -202.978
#     Bayesian info crit = -199.991
# [[Variables]]
#     tau:         675.555208 +/- 17.04116 (2.52%) (init= 769.6494)
#     offset:      0.01120525 +/- 0.004511 (40.26%) (init= 0.01619259)
#     amplitude:   0.50117997 +/- 0.004530 (0.90%) (init= 0.499784)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(offset, amplitude)         = -0.900
#     C(tau, offset)               = -0.777
#     C(tau, amplitude)            =  0.564

# %% [markdown]
# # Measurement set 2

# %% [markdown]
# In this measurement set I fixed the peak at very low wait time. The reason turned out to be that it did not filter out the traces that did not start loaded.

# %%
data = qc.load_data('2016-09-09/#001_ELRLR_calibration_12-04-14')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-09/#002_DC_sweep_12-15-35')
plotQ = qc.MatPlot()
plotQ.add(data.DC_voltage)

# %%
data = qc.load_data('2016-09-09/#006_T1_data_13-03-00')
T1_wait_times = data.T1_wait_time_set[0]
T1_wait_times_sorted = np.sort(T1_wait_times)
idx_sorted = np.argsort(T1_wait_times)

max_idx = np.argmin([~np.isnan(np.sum(datarow)) for datarow in data.up_proportion])
print('Number of successful sweeps: {}'.format(max_idx))
vals = data.up_proportion[:max_idx]
vals_sorted = vals[:,idx_sorted]
vals_mean_sorted = np.mean(vals_sorted,axis=0)
vals_std_sorted = np.std(vals_sorted,axis=0)
vals_std_mean_sorted = vals_std_sorted/np.sqrt(max_idx)


fig = plt.figure()
ax = fig.gca()
for datarow in vals_sorted:
    ax.plot(T1_wait_times_sorted, datarow, 'ok', ms=3, alpha=0.2)
(_, caps, _) = ax.errorbar(T1_wait_times_sorted, vals_mean_sorted, yerr=vals_std_mean_sorted, 
                           marker='o', linestyle='',ms=10)
for cap in caps:
    cap.set_markeredgewidth(3)
    
# Fitting 
mod = fit_toolbox.ExponentialFit()
result=mod.perform_fit(T1_wait_times_sorted,vals_mean_sorted)#, weights=1/np.power(vals_std_mean_sorted,2))
print('T1 time: {:.0f} ms'.format(result.best_values['tau']))
plt.plot(T1_wait_times_sorted, result.best_fit, 'r-')

ax.set_xscale("log")
ax.set_xlim([0.9*T1_wait_times_sorted[0], 1.1*T1_wait_times_sorted[-1]])
ax.set_ylim([0, 0.5])

ax.set_xlabel('Wait time (ms)')
ax.set_ylabel('Up population')
print(result.fit_report())
# Out:
# Number of successful sweeps: 21
# <img src="data:image/png;base64,...">
# T1 time: 683 ms
# [[Model]]
#     Model(fit_function)
# [[Fit Statistics]]
#     # function evals   = 23
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 0.001
#     reduced chi-square = 0.000
#     Akaike info crit   = -195.087
#     Bayesian info crit = -192.100
# [[Variables]]
#     offset:      0.01742750 +/- 0.008661 (49.70%) (init= 0.02829019)
#     tau:         682.696649 +/- 68.67469 (10.06%) (init= 1007.75)
#     amplitude:   0.20007511 +/- 0.008307 (4.15%) (init= 0.2159628)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(offset, amplitude)         = -0.961
#     C(offset, tau)               = -0.882
#     C(tau, amplitude)            =  0.786

# %% [markdown]
# # Measurement set 1

# %% [markdown]
# ## DC scan for empty voltage level

# %%
data = qc.load_data('2016-09-08/#009_DC_sweep_19-51-04')
plotQ = qc.MatPlot()
plotQ.add(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-08/#012_DC_sweep_20-38-56')
plotQ = qc.MatPlot()
plotQ.add(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-08/#013_ELRLR_calibration_20-59-35')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-08/#016_T1_data_21-39-46')
T1_wait_times = data.T1_wait_time_set[0]
T1_wait_times_sorted = np.sort(T1_wait_times)
idx_sorted = np.argsort(T1_wait_times)

max_idx = np.argmin([~np.isnan(np.sum(datarow)) for datarow in data.up_proportion])
print('Number of successful sweeps: {}'.format(max_idx))
vals = data.up_proportion[:max_idx]
vals_sorted = vals[:,idx_sorted]
vals_mean_sorted = np.mean(vals_sorted,axis=0)
vals_std_sorted = np.std(vals_sorted,axis=0)
vals_std_mean_sorted = vals_std_sorted/np.sqrt(max_idx)


fig = plt.figure()
ax = fig.gca()
for datarow in vals_sorted:
    ax.plot(T1_wait_times_sorted, datarow, 'ok', ms=3, alpha=0.2)
(_, caps, _) = ax.errorbar(T1_wait_times_sorted, vals_mean_sorted, yerr=vals_std_mean_sorted, 
                           marker='o', linestyle='',ms=10)
for cap in caps:
    cap.set_markeredgewidth(3)
    
# Fitting 
mod = fit_toolbox.ExponentialFit()
result=mod.perform_fit(T1_wait_times_sorted,vals_mean_sorted, weights=1/np.power(vals_std_mean_sorted,2))
print('T1 time: {:.0f} ms'.format(result.best_values['tau']))
plt.plot(T1_wait_times_sorted, result.best_fit, 'r-')

ax.set_xscale("log")
ax.set_xlim([0.9*T1_wait_times_sorted[0], 1.1*T1_wait_times_sorted[-1]])
ax.set_ylim([0, 0.5])

ax.set_xlabel('Wait time (ms)')
ax.set_ylabel('Up population')
print(result.fit_report())
# Out:
# Number of successful sweeps: 23
# <img src="data:image/png;base64,...">
# T1 time: 217 ms
# [[Model]]
#     Model(fit_function)
# [[Fit Statistics]]
#     # function evals   = 71
#     # data points      = 20
#     # variables        = 3
#     chi-square         = 20332269.527
#     reduced chi-square = 1196015.855
#     Akaike info crit   = 282.640
#     Bayesian info crit = 285.627
# [[Variables]]
#     amplitude:   0.18881658 +/- 0.025373 (13.44%) (init= 0.407826)
#     tau:         216.958943 +/- 79.10706 (36.46%) (init= 115.3862)
#     offset:      0.07781278 +/- 0.007730 (9.93%) (init= 0.07188406)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(amplitude, tau)            = -0.542
#     C(tau, offset)               = -0.364
#     C(amplitude, offset)         = -0.169
