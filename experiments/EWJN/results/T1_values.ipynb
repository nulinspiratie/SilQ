# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib nbagg

# %%
T1_values = np.array([[3,1154 ],[3.5,781],[4,661]])

# %%
plt.plot(T1_values[:,0]**5, 1/T1_values[:,1], 'o-')
# B_values = np.arange(3,4.1,0.1)
# B5 = B_values**5/3e5
# plt.plot(B_values, B5)
# Out:
# <img src="data:image/png;base64,...">
