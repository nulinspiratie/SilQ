# %%
import os
import numpy as np
from matplotlib import pyplot as plt

import qcodes as qc
from silq.analysis import fit_toolbox
qc.data.data_set.DataSet.default_io.base_location = 'E:\EWJN\data'
loc_provider = qc.data.location.FormatLocation(fmt='{date}/#{counter}_{name}_{time}')
qc.data.data_set.DataSet.location_provider=loc_provider
# %matplotlib notebook
# Out:
# <style>.qcodes-output-view:not(.ui-draggable) {
#     bottom: 0;
#     right: 5px;
# }
# .qcodes-output-view {
#     position: fixed;
#     z-index: 999;
#     background-color: #fff;
#     box-shadow: 0 0 12px 1px rgba(87, 87, 87, 0.2);
# }
#
# .qcodes-output-header {
#     float: right;
# }
#
# .qcodes-highlight {
#     animation: pulse 1s linear;
#     background-color: #fa4;
# }
#
# @keyframes pulse {
#     0% {
#         background-color: #f00;
#     }
#     100% {
#         background-color: #fa4;
#     }
# }
#
# .qcodes-process-list {
#     float: left;
#     max-width: 780px;
#     margin: 3px 5px 3px 10px;
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
# .qcodes-output-view[qcodes-state=minimized] .qcodes-process-list {
#     max-width: 300px;
# }
#
# .qcodes-output-view span {
#     padding: 2px 6px 3px 12px;
# }
#
# .qcodes-output-view .btn {
#     margin: 0 3px 0 0;
# }
#
# .qcodes-output-view[qcodes-state=docked] .qcodes-docked,
# ...

# %% [markdown]
# # Measurement set 1
#
# We had quite some hiccups with the system. After the measurement at 5T on Saturday night, Steffi tried to ramp down to 2.5T. However, the switch heater did not turn off. Therefore, when the magnetic current source tried to ramp down to zero current, it actually lowered the magnetic field down to zero. Consequently, the temperature increased significantly. This morning we had a look, and were able to successfully ramp the magnet back to 2.5T. We should keep this in mind, in case this happens in the future again.

# %%
data = qc.load_data('2016-09-12/#001_DC_sweep_12-03-30')
plotQ = qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Very strange, at some point the traces seemed much more smeared out. After going downstairs, it turned out that DS was unresponsive. I reset the SIM channel, and am now redoing DC for a more narrow segment

# %%
data = qc.load_data('2016-09-12/#003_DC_sweep_12-20-22')
plotQ = qc.MatPlot(data.DC_voltage)
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-12/#004_ELRLR_calibration_12-25-12')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %%
data = qc.load_data('2016-09-12/#007_ELRLR_calibration_13-18-30')

plot = qc.MatPlot(subplots=(2,2), figsize=(10,8))
plot.add(data.contrast, subplot=1, nticks=6)
plot.add(data.dark_counts, subplot=2, nticks=6)
plot.add(data.fidelity_load, subplot=3, nticks=6)
plot.add(data.fidelity_empty, subplot=4, nticks=6)
plot.fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Operating point:
#
# TGAC(1.822)
# DF_DS(2.563)
#
# fidelity_empty: 1.000
# fidelity_load: 0.937
# fidelity_read: 0.766
# up_proportion: 0.510
# dark_counts: 0.043
# contrast: 0.467

# %%
data = qc.load_data('2016-09-12/#009_variable_read_13-30-08')
plot = qc.MatPlot(data.Channel_A_signal)
# Out:
# <img src="data:image/png;base64,...">
